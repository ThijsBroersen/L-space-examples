// %%
import $ivy.`eu.l-space::lspace-core:0.5.0.1`
import $ivy.`eu.l-space::lspace-parse-circe:0.5.0.1`

// %%
import lspace._
import lspace.Implicits.SyncGuide.guide
// Out:
// import lspace._
//
// import lspace.Implicits.SyncGuide.guide

// %%
import lspace.util.SampleGraph
import lspace.util.SampleGraph._
val graph = lspace.structure.Graph("mygraph")
{SampleGraph.loadSocial(graph)}: Unit
// Out:
// import lspace.util.SampleGraph
//
// import lspace.util.SampleGraph._
//
// graph: Graph = graph:mygraph

// %%
g.N.count.withGraph(graph).head
// Out:
// res12: Long = 10L

// %%
g.N.hasLabel(ontologies.person).out("name").withGraph(graph).toList
// Out:
// res14: List[Any] = List("Kevin", "Stan", "Garrison", "Yoshio", "Levi", "Gray")

// %%
g.N.hasLabel(ontologies.place).out("name").withGraph(graph).toList
// Out:
// res15: List[Any] = List(
//   "Crystal Springs",
//   "Haridwar",
//   List("Talca", "Tal Ca"),
//   "San Jos\u00e9 de Maipo"
// )

// %%
g.N.has("name", P.eqv("Levi")).out(properties.knows).out("name").withGraph(graph).toList
// Out:
// res17: List[Any] = List("Gray", "Yoshio")
